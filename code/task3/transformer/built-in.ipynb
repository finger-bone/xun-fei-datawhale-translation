# %%
import torch
import torch.nn as nn
import numpy as np
from torch import Tensor

# %%
from transformers import AutoTokenizer
from torch.utils.data.dataset import Dataset
from torch.utils.data.dataloader import DataLoader

# %%
class MTTrainDataset(Dataset):
    
    def __init__(self, train_path, dic_path):
        self.terms = [
            {"en": l.split("\t")[0], "zh": l.split("\t")[1]} for l in open(dic_path).read().split("\n")[:-1]
        ]
        self.data = [
            {"en": l.split("\t")[0], "zh": l.split("\t")[1]} for l in filter(
                lambda x: len(x) < 512,
                open(train_path).read().split("\n")[:-1]
            )
        ]
        self.en_tokenizer = AutoTokenizer.from_pretrained("google-bert/bert-base-uncased", cache_dir="../../cache")
        self.ch_tokenizer = AutoTokenizer.from_pretrained("google-bert/bert-base-chinese", cache_dir="../../cache")
        # self.en_tokenizer.add_tokens([
        #     term["en"] for term in self.terms
        # ])
        # self.ch_tokenizer.add_tokens([
        #     term["zh"] for term in self.terms
        # ])
                
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, index) -> dict:
        return {
            "src": Tensor(self.en_tokenizer.encode(self.data[index]["en"])).to(device, dtype=torch.long), 
            "trg": Tensor(self.ch_tokenizer.encode(self.data[index]["zh"])).to(device, dtype=torch.long)
        }
    
    def get_raw(self, index):
        return self.data[index]

# %%
train_data = MTTrainDataset("./data/train.txt", "./data/en-zh.dic")

# %%
# 位置编码
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        import math
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)

# Transformer
class TransformerModel(nn.Module):
    def __init__(self, src_tk, tgt_tk, d_model, nhead, num_encoder_layers, num_decoder_layers, dim_feedforward, dropout):
        super(TransformerModel, self).__init__()
        self.transformer = nn.Transformer(d_model, nhead, num_encoder_layers, num_decoder_layers, dim_feedforward, dropout)
        self.src_embedding = nn.Embedding(len(src_tk), d_model)
        self.tgt_embedding = nn.Embedding(len(tgt_tk), d_model)
        self.positional_encoding = PositionalEncoding(d_model, dropout)
        self.fc_out = nn.Linear(d_model, len(tgt_tk))
        self.src_vocab = src_tk
        self.tgt_vocab = tgt_tk
        self.d_model = d_model

    def forward(self, src, tgt):
        # 调整src和tgt的维度
        src = src.transpose(0, 1)  # (seq_len, batch_size)
        tgt = tgt.transpose(0, 1)  # (seq_len, batch_size)

        src_mask = self.transformer.generate_square_subsequent_mask(src.size(0)).to(src.device)
        tgt_mask = self.transformer.generate_square_subsequent_mask(tgt.size(0)).to(tgt.device)

        src_padding_mask = (src == 0).transpose(0, 1)
        tgt_padding_mask = (tgt == 0).transpose(0, 1)

        src_embedded = self.positional_encoding(self.src_embedding(src) * math.sqrt(self.d_model))
        tgt_embedded = self.positional_encoding(self.tgt_embedding(tgt) * math.sqrt(self.d_model))

        output = self.transformer(src_embedded, tgt_embedded,
                                  src_mask, tgt_mask, None, src_padding_mask, tgt_padding_mask, src_padding_mask)
        return self.fc_out(output).transpose(0, 1)

# %%
device = "cuda"

# %%
def initialize_model(src_tk, tgt_tk, d_model=512, nhead=8, num_encoder_layers=6, num_decoder_layers=6, dim_feedforward=2048, dropout=0.1):
    model = TransformerModel(src_tk, tgt_tk, d_model, nhead, num_encoder_layers, num_decoder_layers, dim_feedforward, dropout)
    return model

# %%
en_tokenizer = AutoTokenizer.from_pretrained("google-bert/bert-base-uncased", cache_dir="../../../cache")
ch_tokenizer = AutoTokenizer.from_pretrained("google-bert/bert-base-chinese", cache_dir="../../../cache")

# %%
import math

# %%
model = initialize_model(en_tokenizer, ch_tokenizer).to(device)
# Out:
# /home/tx/miniconda3/envs/backend/lib/python3.10/site-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %%
model.train()
pass

# %%
def collate_fn(batch):
    src = torch.nn.utils.rnn.pad_sequence([x["src"] for x in batch], batch_first=True, padding_value=0)
    trg = torch.nn.utils.rnn.pad_sequence([x["trg"] for x in batch], batch_first=True, padding_value=0)
    return src, trg

# %%
# set random values for the model
for p in model.parameters():
    if p.dim() > 1:
        nn.init.xavier_uniform_(p)

# %%
def train(
    epochs: int=10,
    steps: int | None=None,
    batch_size: int=4,
    logging_times: int=200,
    check_each_epoch_times: int=3,
) -> list[float]:
    optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, betas=(0.9, 0.98), eps=1e-9)
    # scheduler = torch.optim.lr_scheduler.StepLR(optimizer, scheduler_steps, gamma=gemma)
    criterion = nn.CrossEntropyLoss(ignore_index=0)
    losses = []
    logging_steps = (steps if steps is not None else (len(train_data) // batch_size)) // logging_times
    check_steps = (steps if steps is not None else (len(train_data) // batch_size)) // check_each_epoch_times
    from tqdm.notebook import tqdm
    data_loader = DataLoader(train_data, batch_size=batch_size, collate_fn=collate_fn)
    for epoch in tqdm(range(epochs)):
        for step, (src, trg) in tqdm(
            enumerate(data_loader), total=len(data_loader) if steps is None else steps, desc=f"Epoch: {epoch}"
        ):
            src = src.to(device)
            trg = trg.to(device)
            optimizer.zero_grad()
            output = model(src, trg[:, :-1])
            loss = criterion(output.reshape(-1, output.size(-1)), trg[:, 1:].reshape(-1))
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            # scheduler.step()
            losses.append(loss.item())
            if steps is not None and step >= steps:
                break
            if step % logging_steps == 0:
                print(f"Epoch: {epoch}, Step: {step}, Loss: {losses[-1]}")
                print(f"avg_loss: {np.mean(losses[-logging_steps:])}")
                print(f"Input: {train_data.en_tokenizer.decode(src[0].tolist())}")
                print(f"Prediction: {train_data.ch_tokenizer.decode(output.argmax(-1)[0].tolist())}")
                print(f"Target: {train_data.ch_tokenizer.decode(trg[0].tolist())}")
                print("=" * 100)
            if step % check_steps == 0:
                torch.save(model.state_dict(), f"./m_{step}_{epoch}.pth")
    return losses

# %%
losses = train(epochs=3, steps=None, logging_times=100, batch_size=32)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch: 0:   0%|          | 0/4616 [00:00<?, ?it/s]
# /home/tx/miniconda3/envs/backend/lib/python3.10/site-packages/torch/nn/functional.py:5137: UserWarning: Support for mismatched src_key_padding_mask and mask is deprecated. Use same type for both instead.
#   warnings.warn(
# /home/tx/miniconda3/envs/backend/lib/python3.10/site-packages/torch/nn/functional.py:5137: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# Epoch: 0, Step: 0, Loss: 9.982889175415039
# avg_loss: 9.982889175415039
# Input: [CLS] there's a tight and surprising link between the ocean's health and ours, says marine biologist stephen palumbi. he shows how toxins at the bottom of the ocean food chain find their way into our bodies, with a shocking story of toxic contamination from a japanese fish market. his work points a way forward for saving the oceans'health - - and humanity's. [SEP]
# Prediction: 実 桨 假load 2012ーションetload酩load 矍ff 假膏et chan mems籠 鏈 86 鉚 鉚ａloadload 假 chan chan屑 outlet 蓓 組ff烷膏 戈ａａーションloadads 2012烷ａａ 恚 氤ーション陣鳳ａ湾etload 薦load 鉚load 2012 捋湾ffff 缱load 2012 chan陣 雹ffａ湾et总ーション頰 捋loadloadet 捋烷 chan烷湾loadloadload veload韜槍load chanload 蓓ａ exo酩 捋 蟋 chan湾load chanloadningａ 2012ａ槍loadet chan頰 捋ff 2012 chan淼 蓓
# Target: [CLS] 生 物 学 家 史 蒂 芬 · 帕 伦 认 为 ， 海 洋 的 健 康 和 我 们 的 健 康 之 间 有 着 紧 密 而 神 奇 的 联 系 。 他 通 过 日 本 一 个 渔 场 发 生 的 让 人 震 惊 的 有 毒 污 染 的 事 件 ， 展 示 了 位 于 海 洋 食 物 链 底 部 的 有 毒 物 质 是 如 何 进 入 我 们 的 身 体 的 。 他 的 工 作 主 要 是 未 来 拯 救 海 洋 健 康 的 方 法 [UNK] [UNK] 同 时 也 包 括 人 类 的 。 [SEP]
# ====================================================================================================
# Epoch: 0, Step: 46, Loss: 7.133336544036865
# avg_loss: 8.349827465803727
# Input: [CLS] and you can get at them remotely, if you happen to have a laptop. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的
# Target: [CLS] 如 果 你 有 一 台 笔 记 本 电 脑 ， 那 么 你 就 可 以 进 行 远 程 下 载 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 92, Loss: 6.250809669494629
# avg_loss: 6.594372863354891
# Input: [CLS] it means " surrender of self - interest to the will of allah. " [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP]
# Target: [CLS] 是 说 个 人 利 益 要 顺 从 真 主 安 拉 的 意 愿 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 138, Loss: 6.387502193450928
# avg_loss: 6.192373296488887
# Input: [CLS] but there is really no longer any major debate over the fact that cooperative arrangements have moved from a peripheral role to a central role in biology, from the level of the cell to the level of the ecology. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的
# Target: [CLS] 但 是 ， 关 于 生 物 学 中 合 作 机 制 已 经 日 渐 重 要 这 个 事 实 ， 再 不 会 有 任 何 大 的 辩 论 ， 从 细 胞 到 整 个 生 态 系 统 都 是 如 此 。 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 184, Loss: 6.489036560058594
# avg_loss: 6.196793400723001
# Input: [CLS] and they turn up the lights. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP]
# Target: [CLS] 然 后 他 们 打 开 了 灯 。 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 230, Loss: 6.033832550048828
# avg_loss: 6.109882727913234
# Input: [CLS] anyway, it was aveling, and when they met, darwin challenged aveling, " why do you call yourselves atheists? " [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的
# Target: [CLS] 无 论 如 何 ， 其 实 是 [UNK], 当 他 们 相 遇 的 时 候 ， 达 尔 文 向 [UNK] 提 出 挑 战 ， [UNK] 为 什 么 你 叫 自 己 做 无 神 论 者 呢 ？ [UNK] [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 276, Loss: 5.948575973510742
# avg_loss: 6.1345265533613125
# Input: [CLS] and i'm going to kick it to keith to explain why that's important from a technical standpoint. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 我 我 我 我 我 我 我 我 我 我 我 我 的 的 的 的 的 的 的 的 的 的 的 的 的 的 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] 的 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP]
# Target: [CLS] 下 面 我 把 话 筒 给 基 斯 ， 他 将 从 技 术 角 度 解 释 为 什 么 这 很 重 要 。 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 322, Loss: 6.1812238693237305
# avg_loss: 6.162010493485824
# Input: [CLS] one very young, one a little more mature. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 我 我 [SEP] [SEP] [SEP] 我 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP]
# Target: [CLS] 一 个 很 年 轻 ， 一 个 更 加 成 熟 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 368, Loss: 6.172639846801758
# avg_loss: 6.013001587079919
# Input: [CLS] or the gallup poll that showed that seven in 10 americans believed that a nuclear war would happen, and that at least 50 percent of our population was going to be killed. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 的 们 们 们 们 的 。 。 的 。 。 。 。 。 。 。 的 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 们 。 。 。 。 。 。 。 [SEP] 。 [SEP] 。 [SEP] 。 。 。 。 。 。 。 。 。 。 。 [SEP] 。 [SEP] [SEP] [SEP] [SEP] [SEP] 。 。 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] 。 。 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] 。 。 。 。 [SEP] 。 。 。 [SEP] [SEP] [SEP] [SEP] 。 [SEP] [SEP] [SEP] 。 。 。 。 [SEP] [SEP]
# Target: [CLS] 或 者 盖 洛 普 民 意 调 查 显 示 七 成 美 国 人 相 信 未 来 将 会 发 生 核 战 争 并 且 至 少 我 们 一 半 人 口 将 会 死 于 战 争 。 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 414, Loss: 5.6112542152404785
# avg_loss: 5.9288118818531865
# Input: [CLS] plank number three : tell your story. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 我 我 我 我 的 。 的 。 。 。 [SEP] 。 。 [SEP] 。 [SEP] [SEP] [SEP] 。 。 [SEP] [SEP] 。 [SEP] [SEP] [SEP] 。 [SEP] [SEP] 。 [SEP] [SEP] 。 [SEP] [SEP] [SEP] 。 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP]
# Target: [CLS] 重 点 三 ： 讲 述 你 的 故 事 。 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 460, Loss: 6.147247791290283
# avg_loss: 5.866333681604137
# Input: [CLS] the other lady tells me to wear " adorable. " [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 们 们 们 的 的 的 是 们 的 [SEP] 。 们 。 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] 。 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] 。 [SEP] [SEP] 。 [SEP] [SEP] [SEP] [SEP] 。 。 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] 。 [SEP] 。 。 [SEP]
# Target: [CLS] 另 一 个 则 告 诉 我 涂 [UNK] 粉 可 爱 [UNK] [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 506, Loss: 5.888063430786133
# avg_loss: 5.957653470661329
# Input: [CLS] and i want to just show you a little bit about why. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 们 是 是 ， 的 的 的 是 ， 的 的 个 的 个 个 个 [SEP] 的 [SEP] 的 的 [SEP] 。 。 的 的 。 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] 。 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] 。 的 [SEP] [SEP] [SEP] [SEP] [SEP] 的 [SEP] 的 。 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP]
# Target: [CLS] 我 只 是 想 稍 微 给 你 们 展 示 一 下 这 是 为 什 么 。 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 552, Loss: 5.773974895477295
# avg_loss: 5.879122868828151
# Input: [CLS] so you see it that way. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 们 们 我 们 们 ， ， 的 个 个 的 。 。 。 。 个 。 。 。 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] 。 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] 。 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP]
# Target: [CLS] 所 以 你 所 看 到 的 就 是 同 样 明 暗 的 两 个 瓷 砖 的 景 象 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 598, Loss: 6.0326385498046875
# avg_loss: 5.790086082790209
# Input: [CLS] okay, same thing is true in our workplaces. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 我 我 我 我 的 的 [SEP] 的 的 的 的 。 个 的 。 ， 们 ， 。 的 。 。 。 。 。 。 。 的 。 。 的 。 。 。 。 。 。 的 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 的 。 。 。 。 。 的 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 的 。 。 。 。 。 。 。 。 。 。 的 。 。 。 。 。 。 。 。 。 。 。 。 。
# Target: [CLS] （ 笑 声 ） 好 了 。 同 样 的 事 情 也 发 生 在 我 们 工 作 的 地 方 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 644, Loss: 6.025984287261963
# avg_loss: 5.735388838726541
# Input: [CLS] what we want to do is mix in all types of data. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 们 一 ， ， 的 的 的 的 个 的 。 。 [SEP] [SEP] 的 [SEP] [SEP] [SEP] 。 [SEP] 。 [SEP] [SEP] 。 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] 。 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] 。 [SEP] [SEP] [SEP] [SEP]
# Target: [CLS] 我 们 要 做 的 是 混 合 所 有 类 型 的 数 据. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 690, Loss: 5.8368239402771
# avg_loss: 5.979842735373455
# Input: [CLS] and because of this left weighting, the average is actually here, way to the left. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 这 是 是 是 的 的 的 的 的 的 的 的 们 是 的 的 的 的 的 的 的 是 的 是 的 们 的 的 的 的 的 的 [SEP] 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的
# Target: [CLS] 因 为 这 个 曲 线 的 重 心 左 倾 ， 所 以 平 均 值 实 际 上 是 在 这 里 ， 非 常 靠 近 左 端 。 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 736, Loss: 5.920004844665527
# avg_loss: 5.8403008709783135
# Input: [CLS] well, we're going to be sending robotic missions to mars long in advance of human missions. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 是 是 个 的 的 的 的 的 的 的 个 的 的 个 的 个 们 个 个 的 个 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的
# Target: [CLS] 那 是 因 为 经 过 长 期 的 载 人 火 星 任 务 后 我 们 将 会 将 机 器 人 送 上 火 星 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 782, Loss: 6.041540145874023
# avg_loss: 5.8101254546124
# Input: [CLS] all right, here it is backwards, and see if you can hear the hidden messages that are supposedly in there. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 的 的 我 一 我 我 的 的 的 的 的 的 [SEP] 的 的 们 的 个 的 的 的 的 的 的 的 的 的 的 。 。 [SEP] 的 的 的 。 的 的 的 的 的 的 的 的 的 的 的 的 的 。 的 的 的 的 的 。 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 。 的 的 的 的 。 。 的 的
# Target: [CLS] 好 的 ， 接 下 来 是 倒 转 的 版 本 。 看 看 你 是 否 听 得 出 里 面 应 该 藏 有 的 讯 息 。 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 828, Loss: 6.186122417449951
# avg_loss: 5.857993696046912
# Input: [CLS] i spent 20 years in interviews with african farmers who were on the verge of famine. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 们 我 的 的 [SEP] 的 的 我 的 我 的 [SEP] 的 的 的 [SEP] 的 的 [SEP] [SEP] [SEP] [SEP] 的 [SEP] 们 的 [SEP] [SEP] [SEP] [SEP] [SEP] 的 [SEP] 我 的 [SEP] [SEP] [SEP] 的 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP]
# Target: [CLS] 我 在 非 洲 工 作 了 20 年 ， 终 日 奔 走 于 饥 饿 的 非 洲 农 民 中 间 我 在 非 洲 工 作 了 20 年 ， 终 日 奔 走 于 饥 饿 的 非 洲 农 民 中 间 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 874, Loss: 5.785040855407715
# avg_loss: 5.798081325448078
# Input: [CLS] as the senior officer approaches with a baton, layma stands up with deliberation, reaches her arms up over her head, and begins, very slowly, to untie her headdress that covers her hair. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 我 的 ， ， ， ， ， ， ， ， ， 我 的 的 我 的 ， 的 的 的 的 的 我 我 的 的 的 的 我 的 ， 的 的 的 我 的 ， 的 的 的 的 的 的 的 ， 的 的 的 的 的 [SEP] 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的
# Target: [CLS] 当 高 级 警 官 拿 着 警 棍 向 她 们 靠 近 ， [UNK] 从 容 地 站 起 来 ， 把 双 手 举 高 ， 越 过 她 的 头 ， 开 始 慢 慢 的 解 开 包 着 她 头 发 的 头 巾 。 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 920, Loss: 5.794655799865723
# avg_loss: 5.916761501975682
# Input: [CLS] just for my workshop. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 是 ， 们 的 [SEP] 的 [SEP] 的 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP]
# Target: [CLS] 仅 供 我 的 工 作 组 使 用 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 966, Loss: 5.657974720001221
# avg_loss: 5.654548759045809
# Input: [CLS] lisa harouni : a primer on 3d printing [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 的 。 [SEP] 。 。 。 [SEP] [SEP] 的 。 的 的 的 的 的 的 。 的 的 。 的 的 的 。 的 。 的 。 。 的 的 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 的 。 。 。 。 。 的 的 。 。 。 。 。 。 。 。 。 。 。 。 。 。 的 。 。 。 。 。 。 。 。 。 。 。 。 的 。 。 。 。 的 。 。 。 。 。 的 。 。 。 。
# Target: [CLS] 莉 沙. 哈 鲁 尼 ： [UNK] 打 印 入 门 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 1012, Loss: 5.914484024047852
# avg_loss: 5.7104145754938544
# Input: [CLS] if you look at this diagram of a coral reef, we know a lot about that part up near the top, and the reason we know so much about it is scuba divers can very easily go down there and access it. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 是 我 们 我 个 我 个 的 的 ， ， 的 的 的 们 我 ， 我 的 的 的 个 的 的 的 的 我 的 我 们 我 个 的 我 我 个 我 的 的 的 的 的 的 的 的 的 的 的 的 个 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的
# Target: [CLS] 如 果 你 看 一 下 这 张 珊 瑚 礁 的 图 表 我 们 对 最 上 方 的 那 部 分 了 解 很 多 之 所 以 如 此 ， 是 因 为 水 肺 潜 水 员 能 轻 松 地 下 潜 到 那 里 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 1058, Loss: 5.167638778686523
# avg_loss: 5.794698912164439
# Input: [CLS] that's what they are to you. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 这 们 的 的 们 的 的 的 个 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP]
# Target: [CLS] 他 们 对 你 来 说 是 这 个 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 1104, Loss: 6.073193550109863
# avg_loss: 5.780378922172215
# Input: [CLS] and over here we have, in the words of radiologist israel meisner, " the hand grasping the penis in a fashion resembling masturbation movements. " [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 我 个 么 我 们 我 我 我 我 ， 的 的 的 我 的 的 的 ， 的 的 我 么 我 ， 的 的 我 [SEP] 。 的 。 。 。 的 的 的 的 ， 是 的 的 。 [SEP] [SEP] 的 。 。 。 。 的 的 的 。 的 。
# Target: [CLS] 在 这 呢 ， 我 们 看 看 放 射 科 医 师 以 色 列 · 麦 斯 内 是 怎 么 说 的 吧 ， [UNK] 手 持 阴 茎 的 动 作 近 似 于 自 慰 活 动 。 [UNK] [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 1150, Loss: 5.684017658233643
# avg_loss: 5.750520623248557
# Input: [CLS] now how do we communicate with rats? [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 们 是 么 的 的 。 。 。 [SEP] [SEP] 。 。 [SEP] 题 [SEP] 。 。 。 。 [SEP] 题 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 [SEP] 。 。 。 [SEP] [SEP] 。 [SEP] 。 。 [SEP] [SEP] 。 [SEP] [SEP] [SEP] [SEP] 。 [SEP] 。 。 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] 。 。 界 。 题 。 。 。 。 。 。 [SEP] [SEP] 界 题 [SEP] 。 。 [SEP] [SEP] 。 [SEP] 。 [SEP] 。 [SEP] 。 。 。 。 。 题 。 [SEP] [SEP] [SEP] [SEP] [SEP]
# Target: [CLS] 我 们 怎 么 和 鼠 交 流 呢 ？ [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 1196, Loss: 5.585768699645996
# avg_loss: 5.603858502014823
# Input: [CLS] the reason they settled out is because it's cheaper to settle than to fight the lawsuit - - clearly, two million dollars cheaper in some cases, and much worse if you actually lose. [SEP]
# Prediction: 我 们 在 ， ， 我 我 的 的 个 我 个 我 的 的 的 的 我 的 我 的 的 我 我 的 是 我 我 我 的 个 我 的 是 我 们 是 我 的 们 我 的 [UNK] [UNK] 是 的 的 我 我 。 的 。
# Target: [CLS] 他 们 庭 外 和 解 的 原 因 是 这 比 打 官 司 要 便 宜 很 明 显 ， 有 时 甚 至 要 便 宜 两 百 万 而 且 你 还 很 有 可 能 输 [UNK] [UNK] 如 果 情 况 更 糟 的 话 [SEP]
# ====================================================================================================
# Epoch: 0, Step: 1242, Loss: 5.883236408233643
# avg_loss: 5.709934929142827
# Input: [CLS] he decided to tell it to me and i made a book, from which i'm going to read you some excerpts later. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 们 ， 的 是 我 们 们 的 界 的 们 在 在 在 一 个 的 的 个 的 的 们 的 的 个 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的
# Target: [CLS] 他 决 定 告 诉 我 他 的 故 事 我 将 其 写 成 一 本 书 一 会 儿 我 会 为 各 位 读 些 摘 录 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 1288, Loss: 5.572372913360596
# avg_loss: 5.546474705571714
# Input: [CLS] what this tells us, ethical issues aside, is that... [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 个 是 我 们 们 是 一 。 。 。 始 。 。 。 是 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。 。
# Target: [CLS] 这 告 诉 我 们 不 追 究 道 德 问 题 的 话 就 是 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 1334, Loss: 5.7374267578125
# avg_loss: 5.526572061621624
# Input: [CLS] i'm calling this the great unwind. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 们 们 我 们 在 一 一 个 的 [SEP] 的 的 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP]
# Target: [CLS] 我 们 把 它 称 之 为 一 场 [UNK] 大 松 绑 [UNK] 。 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 1380, Loss: 5.2679548263549805
# avg_loss: 5.585161706675654
# Input: [CLS] you don't just jump into an invitation. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 是 是 的 我 的 [SEP] 我 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP]
# Target: [CLS] 不 能 茫 然 地 接 受 邀 请 。 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 1426, Loss: 5.23862361907959
# avg_loss: 5.396412766498068
# Input: [CLS] now how do the two brains work with each other? [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 是 我 个 果 ， ， 的 一 是 的 的 。 。 [SEP] 。 [SEP] [SEP] 。 。 [SEP] 。 [SEP] [SEP] 。 [SEP] [SEP] 。 [SEP] [SEP] [SEP] 。 。 [SEP] 。 。 [SEP] 。 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] 。 [SEP] [SEP] 。 [SEP] [SEP] [SEP] [SEP] 。 。 。 [SEP] [SEP] [SEP]
# Target: [CLS] 那 么 这 两 个 大 脑 是 如 何 相 互 合 作 的 呢 ？ [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 1472, Loss: 5.344136714935303
# avg_loss: 5.467036599698274
# Input: [CLS] you can say you don't trust newspapers. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 是 以 我 一 们 是 一 。 [SEP] 。 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] 。 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] 。 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP]
# Target: [CLS] 你 可 以 说 你 不 相 信 报 纸 上 的 报 导. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 1518, Loss: 5.273568630218506
# avg_loss: 5.341987361078677
# Input: [CLS] big corporations have an in - built tendency to reinforce past success. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 的 的 的 一 个 的 的 一 的 的 一 的 的 的 的 的 的 的 一 的 [SEP] 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的
# Target: [CLS] 大 公 司 有 一 个 内 在 的 倾 向 要 去 强 化 过 去 的 成 功 。 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 1564, Loss: 5.748248100280762
# avg_loss: 5.3929624246514365
# Input: [CLS] these are not election returns ; these are the percentage of people who are overweight. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 是 的 是 我 作 的 的 的 我 个 的 我 的 是 的 的 的 我 的 [SEP] 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 。 的 的 的 的 。 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 。 的 的 的 的 的 的 的
# Target: [CLS] 这 些 不 是 选 举 反 馈 ， 这 些 是 超 重 人 群 的 比 例 。 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 1610, Loss: 5.172034740447998
# avg_loss: 5.467024772063546
# Input: [CLS] it's aerated, it can be peeled off easily, it doesn't cause any irritation, it works underwater. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 我 ， 我 的 一 个 的 的 的 我 以 有 的 的 的 的 的 的 我 有 的 到 的 的 的 的 我 有 有 有 的 一 的 的 的 是 [SEP] 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的
# Target: [CLS] 其 中 添 注 了 二 氧 化 碳 ， 可 以 被 轻 易 地 揭 掉 ， 不 会 带 来 小 困 扰 ， 而 且 还 具 有 防 水 功 能 。 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 1656, Loss: 5.299289226531982
# avg_loss: 5.401630702226059
# Input: [CLS] it can attack. it can do all kinds of stuff. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 在 ， ， 我 ， ， 的 ， 的 ， ， 的 的 的 的 的 的 的 是 ， ， 的 ， ， 的 的 的 的 的 的 人 的 的 的 ， 的 人 人 人 人 人 人 人 的 人 人 ， 人 是 人 的 人 ， 人 人 人 人 是 人 是 [SEP] 是 人 的 人 人 人 人 是 是 人 人 人 人 是 的 人 人 人 [SEP] 人 人 人 人 是 人
# Target: [CLS] 会 攻 击 ， 等 等 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 1702, Loss: 5.183140277862549
# avg_loss: 5.39355554788009
# Input: [CLS] and walked off. and i didn't expect that, because i expected one of these... [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 ， ， 是 的 始 的 [SEP] 个 一 的 的 的 们 人 的 的 [SEP] 们 在 我 们 的 [UNK] [UNK] 在 的 的 的 [UNK] 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的
# Target: [CLS] 然 后 就 走 开 了 。 这 有 些 出 乎 我 的 意 料 。 我 以 为 她 会 [UNK] [UNK] （ 打 屁 股 ） [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 1748, Loss: 5.129263877868652
# avg_loss: 5.392045352769935
# Input: [CLS] so, you know, people who are in desperate straits can get this. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 是 人 子 的 一 的 的 的 的 的 的 人 的 是 是 以 到 个 的 人 界 的 [SEP] [SEP] 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 人 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的
# Target: [CLS] 那 些 生 活 在 物 资 匮 乏 地 区 的 人 们 正 需 要 这 样 的 东 西 。 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 1794, Loss: 5.880247592926025
# avg_loss: 5.365241423897121
# Input: [CLS] they were not the only ones. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 是 ， 们 在 是 是 我 一 个 人 片 。 的 ， 。 。 。 。 。 。 。 。 。 的 。 。 。 。 人 。 。 人 。 人 人 。 。 。 。 人 。 人 个 人 。 人 。 人 人
# Target: [CLS] 不 过 他 们 并 不 是 唯 一 的 专 利 人 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 1840, Loss: 5.864287853240967
# avg_loss: 5.616521234097688
# Input: [CLS] right? [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: （ 们 ， [SEP] ？ ？ ？ ？ ？ ？ ？ ？ ？ ？ ？ ？ ？ [SEP] ？ ？ ？ [SEP] [SEP] ？ [SEP] 么 ？ [SEP] [SEP] [SEP] ？ ？ ？ [SEP] [SEP] ？ ？ [SEP] [SEP] ？ ？ ？ ？ [SEP] [SEP] ？ ？ ？ ？ ？ [SEP] ？ ？ ？ ？ ？ ？ [SEP] ？ ？ [SEP] ？ ？ [SEP] ？ ？ ？ ？ ？ [SEP] ？
# Target: [CLS] 可 对 ？ [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 1886, Loss: 5.23997688293457
# avg_loss: 5.4209764625715176
# ...
# avg_loss: 5.02399406225785
# Input: [CLS] it does make you wonder if there were, for instance, a massive, extremely popular star trek convention one weekend, who would be minding the store? [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 实 ， 家 们 到 到 的 ， 我 的 人 子 的 我 一 是 一 个 子 的 是 一 的 的 是 国 的 人 [UNK] 的 上 的 的 [UNK] 定 的 些 的 的 的 到 的 [SEP] 。 的 的 。 的 的 的 的 的 。 的 的 。 的 的 的 的 的 的 的 的 的
# Target: [CLS] 确 实 令 你 想 弄 明 白 ， 举 个 例 子 ， 是 不 是 每 周 末 都 有 冗 长 而 普 遍 的 [UNK] 星 际 迷 航 [UNK] 公 约 那 谁 会 来 看 店 ？ [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 2530, Loss: 5.346084117889404
# avg_loss: 5.181526774945467
# Input: [CLS] now here's an interesting comparison. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 在 我 一 人 一 的 事 候 我 [SEP] 的 的 [SEP] [SEP] 的 的 的 的 的 的 的 家 的 方 家 方 人 方 方 方 人 方 家 方 人 方 方 方 家 方 的 人 方 方 方 方 方 方 方 的 方 家 方 方 方 人 方 方 人 方 人 方 人 方 方 人 人 人 方 人 方 方 方 定 人 方 行 方 人 据 人 方 方 方 方 人 方 事 方 方 定
# Target: [CLS] 现 在 有 个 有 趣 的 对 比 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 2576, Loss: 5.272933483123779
# avg_loss: 4.955872608267742
# Input: [CLS] there is interaction of galaxies. we know this. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 是 的 的 上 后 ， 在 一 一 的 的 的 。 [SEP] 们 的 [SEP] 了 个 个 。 [SEP] 的 的 的 的 的 的 的 的 的 的 的 。 的 的 的 。 的 的 的 的 的 的 的 的 的 行 入 的 行 的 的 的 的 的 行 行
# Target: [CLS] 不 同 星 际 之 间 存 在 着 相 互 作 用. 我 们 了 解 这 一 点. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 2622, Loss: 4.75060510635376
# avg_loss: 4.998064414314602
# Input: [CLS] and if the very few that survive pass onto their offspring whatever it was that helped them survive, then those offspring must be better adapted to the circumstances in which all this happened than their parents were. [SEP]
# Prediction: 我 果 我 人 据 在 的 的 的 我 子 造 我 的 子 一 的 一 的 的 在 的 人 何 人 方 。 个 [SEP] 个 人 。 子 个 的 的 我 斯 的 多 的 。 的 的 子 的 造 的
# Target: [CLS] 如 果 少 数 能 活 下 来 ， 遗 传 给 子 孙 有 助 于 它 们 存 活 的 任 何 条 件 那 么 这 些 子 孙 一 定 能 比 祖 先 更 好 的 适 应 周 围 环 境 [SEP]
# ====================================================================================================
# Epoch: 0, Step: 2668, Loss: 5.205911636352539
# avg_loss: 5.031624109848686
# Input: [CLS] he's making a great living. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 们 这 我 多 法 的 。 的 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] 行 [SEP] 。 为 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP]
# Target: [CLS] 他 过 着 很 舒 服 的 生 活 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 2714, Loss: 5.147671222686768
# avg_loss: 5.1243921777476436
# Input: [CLS] so she was like that jazz musician friend you have who never studied music but is a terrific musician ; she just had a feeling for math. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 们 是 我 个 人 斯 是 的 子 [SEP] 的 个 的 我 一 到 生 了 的 的 是 是 一 我 的 的 [SEP] 子 [SEP] 的 们 己 上 我 我 方 的 的 个 人 到 [SEP] [SEP] [SEP] 的 的 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] 的 的 的
# Target: [CLS] 她 就 像 一 些 爵 士 乐 音 乐 家 一 样 ， 从 未 学 过 器 乐 但 却 是 为 杰 出 的 音 乐 家 她 自 身 对 于 数 学 有 一 种 感 情 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 2760, Loss: 5.386003494262695
# avg_loss: 5.019146670465884
# Input: [CLS] so when you discuss and when you plan for the resources and the energy needed for the future, for human beings on this planet, you have to plan for 10 billion. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 为 ， 我 我 们 家 ， 我 我 们 的 的 到 的 的 的 事 术 ， 我 的 ， 要 的 候 我 一 个 人 人 的 的 事 的 的 的 须 的 一 个 年 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的 的
# Target: [CLS] 因 此 ， 当 你 讨 论 ， 当 你 计 划 未 来 人 们 的 资 源 和 能 源 需 求 时 为 了 这 个 星 球 上 的 人 类 你 必 须 为 100 亿 人 进 行 计 划 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 2806, Loss: 5.439815044403076
# avg_loss: 5.274030136025471
# Input: [CLS] and these allegations are false. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 是 人 者 式 是 一 的 的 一 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] 的 的 的 [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] 的 行 的 行 行 行 的 的 的 的 的 的 行 的 [SEP] 的 [SEP] [SEP] 行 行 行 行 行 行 [SEP] 行 行 行 的 入 行 方 的 行 的 行 行 方 行 行 的 行 行 方 行 的 行 行 行
# Target: [CLS] 这 些 指 控 都 是 莫 须 有 的 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 2852, Loss: 4.893504619598389
# avg_loss: 4.966404013011767
# Input: [CLS] what is the appropriate new metaphor for aging? [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 这 么 是 是 这 于 的 的 ， 是 我 我 。 [SEP] 是 是 是 者 样 是 者 是 是 里 。 方 ， 里 子 里 论 是 是 者 度 论 是 学 行 方 家 里 学 斯 续 续 论 续 里 斯
# Target: [CLS] 什 么 才 是 对 年 老 的 恰 当 比 喻 ？ [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 2898, Loss: 4.582963943481445
# avg_loss: 4.999376265898995
# Input: [CLS] this is the camera, and three instruments. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 是 一 续 的 的 我 有 一 年 人 [SEP] 的 [SEP] 的 的 的 者 的 的 者 色 者 者 的 者 者 论 入 者 者 者 的 部 者 续 的 论 者 动 续 论 论 续 定 论 续 续 据 续 据 续 入 续 论 论 论 续 据 方 据 家 续 续 色 续 据 续 续 续 年 论 续 入 续 论 入 论 续 家 续 入 续 的 续 续 续 人 方
# Target: [CLS] 这 是 摄 像 头 ， 还 有 三 个 器 械 。 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 2944, Loss: 4.974588394165039
# avg_loss: 4.984967045162035
# Input: [CLS] so, let me tell you this : when wal - mart achieves 20 percent energy reductions, that's going to be a very big deal. but i'm afraid it's not enough. [SEP] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 我 们 到 诉 我 们 的 [UNK] 斯 斯 斯 的 的 分 的 够 的 的 。 要 方 [SEP] 是 们 为 我 个 有 是 在 [SEP] 者 者 的 的 入 的 的 者 球 定 的 的 者 入 斯 的 的 的 的 。 入 续 。 的 的 的 的 家 的 于 者 者 的 者 的
# Target: [CLS] 让 我 来 告 诉 你 们 ： 沃 尔 玛 降 低 20 % 能 耗 意 义 重 大 。 但 我 认 为 这 还 不 够 。 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 2990, Loss: 5.283844470977783
# avg_loss: 4.922382955965788
# Input: [CLS] whatever it is, a fraction of one percent is not enough. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 行 ， 果 人 个 人 年 子 ， ， 人 个 人 分 ， 一 同 的 ， 子 片 子 子 的 ， 。 。 子 子 方 人 人 。 者 的 的 方 。 者 片 球 球 据 方 片 子 尔 子 球 人 ， 的 球 ， 方 片 系 人 片 年 球 据 年 片 子 方 片 方 球 据 片 球 分 片 人 球 据 人 经 方 据 片 人 据 分 人 片 方 人 脑 脑 尔 据
# Target: [CLS] 无 论 如 何 一 个 百 分 点 中 的 一 小 部 分 是 不 够 的 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 3036, Loss: 4.591458320617676
# avg_loss: 4.939859276232512
# Input: [CLS] well, it's pretty simple. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 常 有 单 的 [SEP] 是 是 是 。 ？ 的 。 ？ ？ ？ ？ ？ ？ 得 ？ ？ ？ ？ ？ ？ ？ 术 者 ？ ？ 论 。 定 ？ 。 论 ？ ？ 化 化 行 行 行 ？ 术 术 者 术 术 行 行 ？ 。 ？ ？ ？ 常 ？
# Target: [CLS] 非 常 简 单 。 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 3082, Loss: 4.48420524597168
# avg_loss: 4.886421670084414
# Input: [CLS] remember we took the book, tore the pages out? [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 家 的 得 到 们 的 得 始 ， ， 的 我 我 ？ [SEP] ， 为 的 部 者 为 过 得 度 入 得 过 入 入 入 论 定 入 过 入 论 得 法 入 论 定 望 论 意 过 入 入 入 入 入 入 入 入 论 入 法 入 定 定 定 入 过 者 过 过 入 入 法 论 过 入 着 过 入 过 论 定 论 过 定 过 过 入 过 定 定 定 定 定 定 论 过 过 过 过 定 过 过 脑
# Target: [CLS] 大 家 记 得 我 们 撕 开 了 书 页 ， 对 吧 ？ [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 3128, Loss: 5.402160167694092
# avg_loss: 4.903910211894823
# Input: [CLS] so essentially, we had our first carbon - neutral volcano. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Prediction: 我 以 我 现 上 ， 我 们 是 一 一 一 个 人 的 的 的 事 度 。 。 。 。 。 洋 度 度 者 度 色 球 病 病 者 事 病 病 定 入 论 入 论 定 年 定 据 入 色 色 片 定 定 入 病 病 定 定 据 据 色 入 据 论
# Target: [CLS] 所 以 实 际 上 ， 我 们 有 了 第 一 个 碳 中 性 的 火 山 ． [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================
# Epoch: 0, Step: 3174, Loss: 5.039724349975586
# avg_loss: 4.914010358893353
# Input: [CLS] and the good thing about perceiving ultraviolet is that you can hear if it's a good day or a bad day to sunbathe, because ultraviolet is a dangerous color, a color that can actually kill us, so i think we should all have this wish to perceive things that we cannot perceive. [SEP]
# Prediction: 我 到 用 斯 的 ， 一 ， ， ， 一 我 是 够 到 了 ， 天 ， 。 。 。 的 同 的 物 。 的 。 。 我 为 我 色 。 的 是 一 我 了 的 的 。 我 的 够 够 用 的 的 的 的 。 [SEP] 为 ， 们 得 到 的 的 用 是 到 的 的 到 道 些 。 们 的 行 。 到 道 。 西 。 [SEP] 。 。 。 。 。 。 。 。 。
# Target: [CLS] 感 应 紫 外 线 的 好 处 则 是 ， 你 能 听 到 说 今 天 的 天 气 适 不 适 合 晒 日 光 浴 ， 因 为 紫 外 线 还 是 比 较 危 险 的 ， 它 能 够 使 人 类 致 死 的 。 因 此 我 觉 得 人 们 应 该 想 要 去 感 知 那 些 我 们 无 法 感 知 的 东 西 。 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ====================================================================================================

# %%
model.train()
pass
